# %%
import json

# %%
def parseJson(json):

# %% [markdown]
# # Main

# %%
f = open('suspicious.json', 'r')
packets = f.read()
# print(packets)
di = json.loads(packets)
print(type(di))

for item in di:
    print(item)
    print()
    
# json_str = json.dumps(packets)
# # print(json_str)
# # print(type(json_str))
# di = json.loads(json_str)
# print(di)
# print(type(di))
# Out:
# <class 'list'>
# ...
